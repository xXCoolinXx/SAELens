# %%
import json

# Load the files

with open(
    "./eval_results/sparse_probing_sae_probes/pythia-160m-deduped_layer_8_identity_sae_custom_sae_0_3275_eval_results.json",
    "r",
) as f:
    context = json.load(f)

with open(
    "./eval_results/sparse_probing_sae_probes/pythia-160m-deduped_layer_8_identity_sae_custom_sae_3276_16383_eval_results.json",
    "r",
) as f:
    token = json.load(f)

with open(
    "./eval_results/sparse_probing_sae_probes/pythia-160m-deduped_layer_8_identity_sae_custom_sae_0_16383_eval_results.json",
    "r",
) as f:
    combined = json.load(f)
